# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# Use the kagglehub client library to attach Kaggle resources like competitions, datasets, and models to your session
# Learn more about kagglehub: https://github.com/Kaggle/kagglehub/blob/main/README.md

import kagglehub
# kagglehub.dataset_download('<owner>/<dataset-slug>')
# Out:
# /kaggle/input/datasets/mdimamhosen/testpdf1/Chatim by Smaranjit Chakraborty(BDebooks.Com).pdf

# %%
# !git clone https://github.com/mdimamhosen/ResearchWorkspace.git
# Out:
# Cloning into 'ResearchWorkspace'...
# remote: Enumerating objects: 224, done.
# remote: Counting objects: 100% (224/224), done.
# remote: Compressing objects: 100% (151/151), done.
# remote: Total 224 (delta 75), reused 197 (delta 53), pack-reused 0 (from 0)
# Receiving objects: 100% (224/224), 667.62 KiB | 9.96 MiB/s, done.
# Resolving deltas: 100% (75/75), done.

# %%
# %cd ResearchWorkspace/EDGE/BanglaDialectDataset
# !ls
# Out:
# /kaggle/working/ResearchWorkspace/EDGE/BanglaDialectDataset
# app.py		    Dockerfile	requirements-paddle.txt  TEAM_WORKFLOW.md
# cli.py		    GUIDE.md	requirements.txt	 tessdata
# data		    KAGGLE.md	requirements-ui.txt
# docker-compose.yml  README.md	src

# %%
# %cd /kaggle/working/ResearchWorkspace
# !git pull origin main
# %cd /kaggle/working/ResearchWorkspace/EDGE/BanglaDialectDataset
# !ls
# !python cli.py -h | head -40
# Out:
# /kaggle/working/ResearchWorkspace
# From https://github.com/mdimamhosen/ResearchWorkspace
#  * branch            main       -> FETCH_HEAD
# Already up to date.
# /kaggle/working/ResearchWorkspace/EDGE/BanglaDialectDataset
# app.py		    Dockerfile	requirements-paddle.txt  TEAM_WORKFLOW.md
# cli.py		    GUIDE.md	requirements.txt	 tessdata
# data		    KAGGLE.md	requirements-ui.txt
# docker-compose.yml  README.md	src
# Traceback (most recent call last):
#   File "/kaggle/working/ResearchWorkspace/EDGE/BanglaDialectDataset/cli.py", line 17, in <module>
#     from src.pipeline import (
#   File "/kaggle/working/ResearchWorkspace/EDGE/BanglaDialectDataset/src/pipeline.py", line 13, in <module>
#     from src.pdf_pages import count_pages, render_pdf_pages
#   File "/kaggle/working/ResearchWorkspace/EDGE/BanglaDialectDataset/src/pdf_pages.py", line 7, in <module>
#     import pymupdf as fitz
# ModuleNotFoundError: No module named 'pymupdf'

# %%
# %cd /kaggle/working/ResearchWorkspace/EDGE/BanglaDialectDataset
# !mkdir -p data/pdfs data/txt
# !cp /kaggle/input/datasets/mdimamhosen/testpdf1/*.pdf data/pdfs/
# !ls -la data/pdfs/
# Out:
# /kaggle/working/ResearchWorkspace/EDGE/BanglaDialectDataset
# total 21120
# drwxr-xr-x 2 root root     4096 Aug  7 16:00  .
# drwxr-xr-x 5 root root     4096 Aug  7 16:00  ..
# -rw-r--r-- 1 root root 21611719 Aug  7 16:00 'Chatim by Smaranjit Chakraborty(BDebooks.Com).pdf'
# -rw-r--r-- 1 root root      219 Aug  7 16:00  .gitkeep

# %%
# !pip install -q paddlepaddle-gpu==3.2.2 -i https://www.paddlepaddle.org.cn/packages/stable/cu118/
# !pip install -q -r requirements.txt

import os, paddle
os.environ["OCR_ENGINE"] = "paddle"
os.environ["PADDLE_OCR_BACKEND"] = "vl"
os.environ["PADDLE_OCR_DEVICE"] = "gpu:0"
os.environ["PADDLE_PDX_DISABLE_MODEL_SOURCE_CHECK"] = "True"

print(paddle.__version__, paddle.is_compiled_with_cuda(), paddle.device.get_device())

# !python cli.py -i data/pdfs -o data/txt --engine paddle --page-start 1 --page-end 2 --force
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 GB 1.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.5/65.5 kB 58.6 kB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 875.6/875.6 kB 14.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.1/13.1 MB 16.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 699.9/699.9 MB 2.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 417.9/417.9 MB 3.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 168.4/168.4 MB 7.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.1/58.1 MB 12.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.2/128.2 MB 7.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 204.1/204.1 MB 5.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.3/135.3 MB 7.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 6.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.2/23.2 MB 9.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.7/80.7 kB 3.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 kB 2.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.1/69.1 kB 5.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 25.8/25.8 MB 76.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 146.8/146.8 kB 12.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 87.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 767.5/767.5 kB 43.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.7/68.7 MB 29.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.2/67.2 kB 4.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.0/6.0 MB 109.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.7/3.7 MB 2.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 3.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.2/79.2 kB 6.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 156.0/156.0 kB 13.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 435.2/435.2 kB 28.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 180.6/180.6 kB 12.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.0/80.0 kB 6.1 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-adk 1.29.0 requires google-cloud-bigquery-storage>=2.0.0, which is not installed.
# ydata-profiling 4.18.4 requires PyYAML<6.1,>=6.0.3, but you have pyyaml 6.0.2 which is incompatible.
# /usr/local/lib/python3.12/dist-packages/paddle/utils/cpp_extension/extension_utils.py:718: UserWarning: No ccache found. Please be aware that recompiling all source files may be required. You can download and install ccache from: https://github.com/ccache/ccache/blob/master/doc/INSTALL.md
#   warnings.warn(warning_message)
# 3.2.2 True gpu:0
# Engine: paddle | mode: quality | DPI: 300 | recursive: False | Discovered PDFs: 1
#   [1/1] data/pdfs/Chatim by Smaranjit Chakraborty(BDebooks.Com).pdf
# Processing: Chatim by Smaranjit Chakraborty(BDebooks.Com).pdf → Chatim by Smaranjit Chakraborty(BDebooks.Com).txt
# Chatim by Smaranjit Chakraborty(BDebooks: 0page [00:00, ?page/s]
# Failed Chatim by Smaranjit Chakraborty(BDebooks.Com).pdf: PaddleOCR / PaddleOCR-VL Python package is missing (paddlepaddle alone is not enough).
# Install BOTH:
#   # Kaggle / GPU:
#   pip install -q paddlepaddle-gpu==3.2.2 -i https://www.paddlepaddle.org.cn/packages/stable/cu118/
#   pip install -q 'paddleocr>=3.0.0' 'paddlex[ocr]>=3.7.0' pymupdf Pillow python-dotenv tqdm
#   # Local CPU:
#   pip install paddlepaddle==3.3.0 -i https://www.paddlepaddle.org.cn/packages/stable/cpu/
#   pip install -r requirements.txt
# Then:
#   python cli.py -i /kaggle/input/datasets/... -o /kaggle/working/txt -r --engine paddle
#   (no need to copy PDFs one-by-one — point -i at the folder)
# Optional: PADDLE_PDX_DISABLE_MODEL_SOURCE_CHECK=True
# Chatim by Smaranjit Chakraborty(BDebooks: 0page [00:02, ?page/s]
#
# Done. ok=0 skipped=0 failed=1
